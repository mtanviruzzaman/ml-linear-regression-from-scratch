# %%
# !pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Using cached scikit_learn-1.7.2-cp313-cp313-macosx_12_0_arm64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.22.0 in /opt/miniconda3/lib/python3.13/site-packages (from scikit-learn) (2.3.3)
# Collecting scipy>=1.8.0 (from scikit-learn)
#   Downloading scipy-1.16.3-cp313-cp313-macosx_14_0_arm64.whl.metadata (62 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Using cached joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Using cached scikit_learn-1.7.2-cp313-cp313-macosx_12_0_arm64.whl (8.6 MB)
# Using cached joblib-1.5.2-py3-none-any.whl (308 kB)
# Downloading scipy-1.16.3-cp313-cp313-macosx_14_0_arm64.whl (20.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.9/20.9 MB 6.4 MB/s eta 0:00:006.4 MB/s eta 0:00:01
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [scikit-learn]0m 3/4 [scikit-learn]
# Successfully installed joblib-1.5.2 scikit-learn-1.7.2 scipy-1.16.3 threadpoolctl-3.6.0

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

import numpy as np

# %%
def produce_data(m, n, lo=0, hi=10):    
    X = np.random.uniform(low=lo, high=hi, size=(m, n))
    w = np.random.uniform(low=-5, high=5, size=(n, 1))
    b = np.random.uniform(low=-5, high=5, size=(m, 1))
    noise = np.random.normal(loc=1, scale=2, size=(m, 1))

    y = X @ w + b + noise
    return X, y

# %%
pipeline = Pipeline(
    [
        ("scaler", StandardScaler()),
        ("model", LinearRegression())
    ]
)

# %%
X, y = produce_data(1000, 1)
pipeline.fit(X, y)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()), ('model', LinearRegression())])

# %%
import matplotlib.pyplot as plt
plt.style.use("dark_background")
# plt.style.use("seaborn-v0_8")

plt.scatter(X, y, color="red")
x_fit = np.array([X[:, 0].min(), X[:, 0].max()]).reshape(-1, 1)
plt.plot(x_fit, pipeline.predict(x_fit), color="blue", lw=5)
plt.show()
